# %% [markdown]
# # Addressing the Avian Housing Crisis

# %%
import pandas as pd

# %%
trees = pd.read_csv("trees.csv")
trees.head()
# Out:
#            id  address_number         street         common_name  \
# 0   754166088          7428.0  MONTICELLO ST               Stump
# 1  1946899269           220.0     BALVER AVE  Linden: Littleleaf
# 2  1431517397          2822.0      SIDNEY ST          Maple: Red
# 3   994063598           608.0     SUISMON ST      Maple: Freeman
# 4  1591838573          1135.0   N NEGLEY AVE       Maple: Norway
#
#     scientific_name  height  width  growth_space_length  growth_space_width  \
# 0             Stump     0.0    0.0                 10.0                 2.0
# 1     Tilia cordata     0.0    0.0                 99.0                99.0
# 2       Acer rubrum    22.0    6.0                  6.0                 3.0
# 3  Acer x freemanii    25.0   10.0                  3.0                 3.0
# 4  Acer platanoides    52.0   13.0                 99.0                99.0
#
#       growth_space_type  ...      neighborhood  council_district  ward  \
# ...

# %%
items = dict()
for index, row in trees.iterrows():
    if row['neighborhood'] not in items:
        items[row['neighborhood']] = 1
    else:
        items[row['neighborhood']] += 1

# %%
items
# Out:
# {'Homewood North': 226,
#  'Oakwood': 19,
#  'South Side Flats': 491,
#  'East Allegheny': 110,
#  'Highland Park': 350,
#  'Stanton Heights': 198,
#  'Sheraden': 148,
#  'Chartiers City': 8,
#  'Elliott': 51,
#  'Morningside': 96,
#  'Bloomfield': 488,
#  'Friendship': 177,
#  'Garfield': 316,
#  'Polish Hill': 133,
#  'Lower Lawrenceville': 203,
#  'Central Northside': 294,
#  'East Liberty': 503,
#  'Central Lawrenceville': 176,
#  'Shadyside': 426,
#  'Allegheny Center': 6,
#  'Homewood South': 198,
#  'Point Breeze North': 119,
#  'East Hills': 136,
#  'Homewood West': 32,
#  'Greenfield': 262,
#  'Hazelwood': 184,
#  'Squirrel Hill South': 498,
#  'Marshall-Shadeland': 163,
#  'Brighton Heights': 278,
#  'North Shore': 115,
#  'Overbrook': 78,
#  'Knoxville': 96,
#  'Brookline': 262,
#  'South Side Slopes': 74,
#  'Arlington': 44,
#  'Arlington Heights': 1,
#  'Carrick': 170,
#  'Bedford Dwellings': 49,
#  'Central Business District': 385,
#  'Bluff': 65,
# ...

# %%
sortedNbhds = sorted(items.items(),key=lambda x:x[1],reverse=True)
sortedNbhds
# Out:
# [('East Liberty', 503),
#  ('Squirrel Hill South', 498),
#  ('South Side Flats', 491),
#  ('Bloomfield', 488),
#  ('Shadyside', 426),
#  ('Squirrel Hill North', 399),
#  ('Central Business District', 385),
#  ('Highland Park', 350),
#  ('Garfield', 316),
#  ('Central Northside', 294),
#  ('Mount Washington', 282),
#  ('Brighton Heights', 278),
#  ('Manchester', 266),
#  ('Point Breeze', 264),
#  ('Greenfield', 262),
#  ('Brookline', 262),
#  ('Strip District', 252),
#  ('Homewood North', 226),
#  ('Lower Lawrenceville', 203),
#  ('Stanton Heights', 198),
#  ('Homewood South', 198),
#  ('Hazelwood', 184),
#  ('Beechview', 184),
#  ('Friendship', 177),
#  ('Central Lawrenceville', 176),
#  ('Carrick', 170),
#  ('Crawford-Roberts', 170),
#  ('Marshall-Shadeland', 163),
#  ('Middle Hill', 151),
#  ('Sheraden', 148),
#  ('North Oakland', 146),
#  ('Lincoln-Lemington-Belmar', 143),
#  ('East Hills', 136),
#  ('Polish Hill', 133),
#  ('Perry North', 130),
#  ('Point Breeze North', 119),
# ...
